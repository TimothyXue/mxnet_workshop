# %% [markdown]
# # Part 2: Google Streetview Competition
#
# In this section, you will compete to train a network to solve the Google Streetview challenge. The goal is give you a feeling for the type of problems AI developers face. Adjust the learning rate schedule to achieve the lowest possible training cost!
#
# ## The Problem
#
# Google regularly takes street view photos to populate Google Maps. To associate each photographed house with an address, Google built computer vision algorithms to read the house number from the image. Today we will train a network for the first phase of this process, which is to identify where in the image the house number is located.
#
# This dataset is a collection of 73,257 images of house numbers. Each image has been annotated by a human with a box around the digits.
#
# <img src="http://ufldl.stanford.edu/housenumbers/examples_new.png" width=500px>
#
# Your goal is to train a network to, given a new image, accurately predict the bounding box on the house number.
#
# ## Network
#
# We have already built the model as a neural network with a stack of different types of layers. The input is the image, and the output has 4 numbers, for the coordinates of the predicted box.
#
#
# <img src="image.png", width=800px>
#
# ## Challenge
#
# 1. When you run the code below, a dashboard will be created with several sliders to adjust the learning rate over four different phases of training.
#
# 2. Run the `dashboard.train()` code to train the model with the current settings. When complete, you will recieve the cost of this current training run, as well as the best cost you have achieved so far.
#
# 3. Adjust the sliders to help the model train to the lowest cost possible. Re-run the `dashboard.train()` code to try another attempt. Good luck!

# %%
# setup datasets
# %matplotlib inline
from svhn import Dashboard

# set up dashboard
dashboard = Dashboard()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2ed3874e-c10b-4338-a0d7-9bfbb6b66271">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d879c720-6088-4e4c-9ab1-c0fe658f0e25"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d879c720-6088-4e4c-9ab1-c0fe658f0e25");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("25156418-a4e0-431a-9b49-23ed82211a8e", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d879c720-6088-4e4c-9ab1-c0fe658f0e25");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd879c720-6088-4e4c-9ab1-c0fe658f0e25' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9f94c007-0671-44dd-96bb-a583eea5d881":{"roots":{"references":[{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e44a988-0342-49d8-af09-f43f601b1743","type":"Line"},{"attributes":{"plot":{"id":"110f31a2-5719-4a61-92a5-1e817cc92836","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b26d6ae-eace-4a7c-a79c-b40fc8169a88","type":"BasicTicker"}},"id":"a7373e6f-dc48-4d40-b727-77208d80e529","type":"Grid"},{"attributes":{"axis_label":"Learning Rate","formatter":{"id":"68dee05b-4f91-4521-bc74-bbcbf5e54878","type":"LogTickFormatter"},"plot":{"id":"110f31a2-5719-4a61-92a5-1e817cc92836","subtype":"Figure","type":"Plot"},"ticker":{"id":"1b43a2a1-30ba-420b-8678-e4bc6f5a1441","type":"LogTicker"}},"id":"318541b7-5951-4d74-9bcc-2d0ec68dc696","type":"LogAxis"},{"attributes":{"plot":{"id":"110f31a2-5719-4a61-92a5-1e817cc92836","subtype":"Figure","type":"Plot"}},"id":"29658225-9cd0-4fd3-b27c-8e0a77603240","type":"SaveTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"12cd8efd-1438-41b6-b9de-00264d415d61","type":"Line"},{"attributes":{},"id":"324031b6-9779-4939-b4b4-bbd605da7e80","type":"BasicTickFormatter"},{"attributes":{"callback":{"id":"a3a6439b-e4d8-4f53-b719-1fa5d12bbd4d","type":"CustomJS"},"end":10,"height":50,"orientation":"vertical","start":0.1,"title":null,"value":3,"width":80},"id":"747ceba8-7286-48a6-9ba6-f38aaa18eb67","type":"Slider"},{"attributes":{"plot":null,"text":""},"id":"79ea1ec1-512c-46a8-bfca-d6486d20d30e","type":"Title"},{"attributes":{"children":[{"id":"8b6cf389-263f-4f73-a1a9-e2f35e5fcf57","type":"Column"},{"id":"8eecec32-972a-43e8-aea0-f9ffe58ae653","subtype":"Figure","type":"Plot"}]},"id":"0123ba48-aad3-488a-8bb7-fe4e2ed90f43","type":"Row"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"968dcb5e-4ccf-4d3d-abba-12369549483a","type":"BoxAnnotation"},{"attributes":{},"id":"4b26d6ae-eace-4a7c-a79c-b40fc8169a88","type":"BasicTicker"},{"attributes":{"axis_label":"Epoch","formatter":{"id":"e38ad7af-eda9-4b5e-bc3d-3d9fbd81320b","type":"BasicTickFormatter"},"plot":{"id":"110f31a2-5719-4a61-92a5-1e817cc92836","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b26d6ae-eace-4a7c-a79c-b40fc8169a88","type":"BasicTicker"}},"id":"a77280d8-3ca8-4d7e-853d-64bc92768939","type":"LinearAxis"},{"attributes":{"children":[{"id":"37449944-6a95-42bc-aa61-05f701595940","type":"WidgetBox"},{"id":"2a07a231-f73b-4579-ba89-04d1793419f1","type":"WidgetBox"},{"id":"d57d1a4f-c121-433e-820e-fb52955928d6","type":"WidgetBox"},{"id":"8f77e243-64b2-49cb-a302-665ab78da4aa","type":"WidgetBox"},{"id":"1e766406-73a6-46ea-a0a6-f9a8493fdc45","type":"WidgetBox"}]},"id":"0b0299bd-f560-4f90-9ec0-befee689c97d","type":"Row"},{"attributes":{"callback":{"id":"5f9f769b-84b9-4d86-9a75-b5d16b79a1af","type":"CustomJS"},"end":10,"height":50,"orientation":"vertical","start":0.1,"title":null,"value":3,"width":80},"id":"b01d16a0-90f6-4b59-948c-ed9e1d61f26c","type":"Slider"},{"attributes":{},"id":"08d66237-06f8-40ef-b5f0-e5d03c488809","type":"ToolEvents"},{"attributes":{"overlay":{"id":"45ba2b04-b35d-4442-b978-1f3775521c3d","type":"BoxAnnotation"},"plot":{"id":"110f31a2-5719-4a61-92a5-1e817cc92836","subtype":"Figure","type":"Plot"}},"id":"7aec48be-695d-40fb-8662-14d4a55bd79e","type":"BoxZoomTool"},{"attributes":{"children":[{"id":"13fdfe45-5387-4465-850c-bff24d1dd108","type":"Slider"}],"height":50,"width":80},"id":"d57d1a4f-c121-433e-820e-fb52955928d6","type":"WidgetBox"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f119fca7-fa32-4d0e-895f-2f31c5374530","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"110f31a2-5719- ...

# %%
dashboard.train()
# Out:
# This run has Cost: 1074.33673565
# Your best run so far has Cost: 1074.33673565
# Note: lower is better.
