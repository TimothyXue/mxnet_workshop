# %% [markdown]
# # Part 2: Google Streetview Competition
#
# In this section, you will compete to train a network to solve the Google Streetview challenge. The goal is give you a feeling for the type of problems AI developers face. Adjust the learning rate schedule to achieve the lowest possible training cost!
#
# ## The Problem
#
# Google regularly takes street view photos to populate Google Maps. To associate each photographed house with an address, Google built computer vision algorithms to read the house number from the image. Today we will train a network for the first phase of this process, which is to identify where in the image the house number is located.
#
# This dataset is a collection of 73,257 images of house numbers. Each image has been annotated by a human with a box around the digits.
#
# <img src="http://ufldl.stanford.edu/housenumbers/examples_new.png" width=500px>
#
# Your goal is to train a network to, given a new image, accurately predict the bounding box on the house number.
#
# ## Network
#
# We have already built the model as a neural network with a stack of different types of layers. The input is the image, and the output has 4 numbers, for the coordinates of the predicted box.
#
#
# <img src="image.png", width=800px>
#
# ## Challenge
#
# 1. When you run the code below, a dashboard will be created with several sliders to adjust the learning rate over four different phases of training.
#
# 2. Run the `dashboard.train()` code to train the model with the current settings. When complete, you will recieve the cost of this current training run, as well as the best cost you have achieved so far.
#
# 3. Adjust the sliders to help the model train to the lowest cost possible. Re-run the `dashboard.train()` code to try another attempt. Good luck!

# %%
# setup datasets
# %matplotlib inline
from svhn import Dashboard

# set up dashboard
dashboard = Dashboard()
# Out:
# Setting up the data...
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="abc73554-fce4-44a3-b8e6-4f872a2363af">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="535b904c-8c07-453c-b20a-9e5784ed7d9e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("535b904c-8c07-453c-b20a-9e5784ed7d9e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("da7ab13a-5177-48e7-a2de-1963899f7ff0", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("535b904c-8c07-453c-b20a-9e5784ed7d9e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '535b904c-8c07-453c-b20a-9e5784ed7d9e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"787f124b-6583-4bb4-a2a4-76fd2bace010":{"roots":{"references":[{"attributes":{"callback":null,"end":4},"id":"b5b82bbe-163d-45ca-a24c-e62cfbd511aa","type":"Range1d"},{"attributes":{},"id":"f33f32f0-96f0-4e22-a021-85d1115f5c09","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y":[]}},"id":"6cccffe4-1de3-4aa9-8afe-91cf1f865c80","type":"ColumnDataSource"},{"attributes":{},"id":"6a60cb68-e1d1-4633-925e-ff448c876ca1","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f305488b-5985-46da-aaad-0df1ef704762","type":"Line"},{"attributes":{"axis_label":"Epoch","formatter":{"id":"a247ff29-33df-4b49-a7f7-ea49b35afc90","type":"BasicTickFormatter"},"plot":{"id":"c47bb1c3-a17d-4dd2-bbc8-8840392dcb28","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcb45662-3646-406d-850e-7be4d62bf6dd","type":"BasicTicker"}},"id":"27697c09-87fb-440e-a142-98ae9fc51124","type":"LinearAxis"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69927e6d-4c7c-4b4f-bc26-adc1d6020ba5","type":"Line"},{"attributes":{"callback":null},"id":"14c6bde5-8f59-4d27-9a7c-f400ebf472ad","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"5b662b1d-e95f-43c9-8952-a75a21037f58","type":"Title"},{"attributes":{"plot":{"id":"cd48a8be-5069-4af0-aa3b-c2bf2ff515ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"b5229b25-b0e4-4769-a0b8-46261e1542de","type":"BasicTicker"}},"id":"6b8873e6-7395-47e0-8f90-fa963259587f","type":"Grid"},{"attributes":{"args":{"source":{"id":"c51b4420-65fc-4825-b8f4-90bfa33bfb8b","type":"ColumnDataSource"}},"code":"\n                var data = source.data;\n                var f = cb_obj.value\n                x = data['x']\n                y = data['y']\n                y[2] = Math.pow(10.0, -1.0 * (10-f))\n                y[3] = Math.pow(10.0, -1.0 * (10-f))\n                source.trigger('change');\n\n                var command = 'dashboard.learn_inputs[1] = ' + f;\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(command)\n            "},"id":"3cd04ee9-b0c7-438d-9837-47dfb5baca42","type":"CustomJS"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"24bc29f9-7598-45dc-be7f-6bfdf030e057","type":"Line"},{"attributes":{},"id":"bcb45662-3646-406d-850e-7be4d62bf6dd","type":"BasicTicker"},{"attributes":{},"id":"92cc5ed3-3eb0-4222-8c15-51eb8f837270","type":"ToolEvents"},{"attributes":{"axis_label":"Learning Rate","formatter":{"id":"68028969-1e03-4a2c-bba3-059d454c7c33","type":"LogTickFormatter"},"plot":{"id":"cd48a8be-5069-4af0-aa3b-c2bf2ff515ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ae14818-abb9-45d1-b922-e6123654d098","type":"LogTicker"}},"id":"3bd249a3-3ebc-4281-b96c-20e1723388c5","type":"LogAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y":[]}},"id":"d8863b33-0d48-4e2c-8d40-9e605ac39c36","type":"ColumnDataSource"},{"attributes":{"callback":{"id":"3cd04ee9-b0c7-438d-9837-47dfb5baca42","type":"CustomJS"},"end":10,"height":50,"orientation":"vertical","start":0.1,"title":null,"value":3,"width":80},"id":"70eb839f-0df3-4184-8c4a-6bca91b812ee","type":"Slider"},{"attributes":{"children":[{"id":"70eb839f-0df3-4184-8c4a-6bca91b812ee","type":"Slider"}],"height":50,"width":80},"id":"ea2734cc-4adf-4a56-a0ec-2b546ca2ac8c","type":"WidgetBox"},{"attributes":{"data_source":{"id":"6cccffe4-1de3-4aa9-8afe-91cf1f865c80","type":"ColumnDataSource"},"glyph":{"id":"69927e6d-4c7c-4b4f-bc26-adc1d6020ba5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f305488b-5985-46da-aaad-0df1ef704762","type":"Line"},"selection_glyph":null},"id":"3d087a65-6032-4c43-a108-5ecf3dc961c6","type":"GlyphRenderer"},{"attributes":{"callback":{"id":"c3ac8575-6106-4f8b-b1dc-f2c4cd4b3245","type":"CustomJS"},"end":10,"height":50,"orientation":" ...

# %%
dashboard.train()
