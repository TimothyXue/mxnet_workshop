# %% [markdown]
# # Part 2: Google Streetview Competition
#
# In this section, you will compete to train a network to solve the Google Streetview challenge. The goal is give you a feeling for the type of problems AI developers face. Adjust the learning rate schedule to achieve the lowest possible training cost!
#
# ## The Problem
#
# Google regularly takes street view photos to populate Google Maps. To associate each photographed house with an address, Google built computer vision algorithms to read the house number from the image. Today we will train a network for the first phase of this process, which is to identify where in the image the house number is located.
#
# This dataset is a collection of 73,257 images of house numbers. Each image has been annotated by a human with a box around the digits.
#
# <img src="http://ufldl.stanford.edu/housenumbers/examples_new.png" width=500px>
#
# Your goal is to train a network to, given a new image, accurately predict the bounding box on the house number.
#
# ## Network
#
# We have already built the model as a neural network with a stack of different types of layers. The input is the image, and the output has 4 numbers, for the coordinates of the predicted box.
#
#
# <img src="image.png", width=800px>
#
# ## Challenge
#
# 1. When you run the code below, a dashboard will be created with several sliders to adjust the learning rate over four different phases of training.
#
# 2. Run the `dashboard.train()` code to train the model with the current settings. When complete, you will recieve the cost of this current training run, as well as the best cost you have achieved so far.
#
# 3. Adjust the sliders to help the model train to the lowest cost possible. Re-run the `dashboard.train()` code to try another attempt. Good luck!

# %%
# setup datasets
# %matplotlib inline
from svhn import Dashboard

# set up dashboard
dashboard = Dashboard()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c7052ca7-33a5-40af-a478-79c0a58ae279">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="78e79143-a6ee-452c-b37e-875c3c0bb089"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("78e79143-a6ee-452c-b37e-875c3c0bb089");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("82b986ab-941b-40b6-b8ba-1739365153a3", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78e79143-a6ee-452c-b37e-875c3c0bb089");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78e79143-a6ee-452c-b37e-875c3c0bb089' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"728c2dd2-25c6-432a-9223-4ef4e40fb6de":{"roots":{"references":[{"attributes":{"args":{"source":{"id":"3ff1b54a-68ff-4bcd-b80e-be9cc2b93369","type":"ColumnDataSource"}},"code":"\n                var data = source.data;\n                var f = cb_obj.value\n                x = data['x']\n                y = data['y']\n                y[0] = Math.pow(10.0, -1.0 * (10-f))\n                y[1] = Math.pow(10.0, -1.0 * (10-f))\n                source.trigger('change');\n\n                var command = 'dashboard.learn_inputs[0] = ' + f;\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(command)\n            "},"id":"c73c3d0e-37e3-4708-a980-82bf3279b43e","type":"CustomJS"},{"attributes":{"plot":{"id":"0697e69a-c545-4285-955b-51c5eed7cbf1","subtype":"Figure","type":"Plot"}},"id":"0c49df4e-3454-46f0-9ed3-9bb66ff57c6f","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1519238e-8cb0-4b65-8847-b647237ee74c","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c20fab10-14e7-43e1-8169-e34ff8870ba1","type":"PanTool"},{"id":"2c2e9938-632b-42e9-bf97-a144a26c6e43","type":"WheelZoomTool"},{"id":"c792c531-a554-4671-99f2-a23d9f519273","type":"BoxZoomTool"},{"id":"0c49df4e-3454-46f0-9ed3-9bb66ff57c6f","type":"SaveTool"},{"id":"b963f72b-5b79-493e-823c-60f2d3098322","type":"ResetTool"},{"id":"ac4d4aaf-d5b4-4cd8-b086-f8fb7ad757f0","type":"HelpTool"}]},"id":"633df051-8699-4f98-a5e0-d3cccfba8163","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"fd30d0d0-7f45-40a9-99af-bd6bb3578df0","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4597d717-6647-4a57-8f0a-c823bb05b2a2","type":"PanTool"},{"id":"99dd92fd-ad47-4e67-87a2-be9b7366e9f3","type":"WheelZoomTool"},{"id":"2c416dec-5cfb-4aee-91aa-8dc83a99c5e7","type":"BoxZoomTool"},{"id":"48dcc1b8-7c25-4cc2-9b9a-454cb7aeedf7","type":"SaveTool"},{"id":"5532ef2b-595a-402f-85e0-fae0b1d182e9","type":"ResetTool"},{"id":"5ea3e000-1a04-4db5-a664-39b6890753d3","type":"HelpTool"}]},"id":"6ea7f6c7-ad90-4328-a8ef-26b26221fc22","type":"Toolbar"},{"attributes":{"axis_label":"Learning Rate","formatter":{"id":"b79acffe-5ab7-4240-a80c-db1320504656","type":"LogTickFormatter"},"plot":{"id":"0697e69a-c545-4285-955b-51c5eed7cbf1","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c5f05d8-b844-4008-87f9-5318e0df2b5b","type":"LogTicker"}},"id":"b4a74fd9-213f-405d-b81c-d4800282a13f","type":"LogAxis"},{"attributes":{"plot":{"id":"0697e69a-c545-4285-955b-51c5eed7cbf1","subtype":"Figure","type":"Plot"}},"id":"b963f72b-5b79-493e-823c-60f2d3098322","type":"ResetTool"},{"attributes":{"callback":{"id":"caa18fe3-3295-4b19-9cdc-4230a9d57c82","type":"CustomJS"},"end":10,"height":50,"orientation":"vertical","start":0.1,"title":null,"value":3,"width":80},"id":"549cad2c-a2b8-466c-9342-da93aeee6eab","type":"Slider"},{"attributes":{"plot":{"id":"0697e69a-c545-4285-955b-51c5eed7cbf1","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e945d41-2e46-464f-ba52-46de2599857c","type":"BasicTicker"}},"id":"8dfc567f-930b-46a2-a1e5-5a6eeaea0a84","type":"Grid"},{"attributes":{"plot":{"id":"0697e69a-c545-4285-955b-51c5eed7cbf1","subtype":"Figure","type":"Plot"}},"id":"2c2e9938-632b-42e9-bf97-a144a26c6e43","type":"WheelZoomTool"},{"attributes":{"ticker":null},"id":"b79acffe-5ab7-4240-a80c-db1320504656","type":"LogTickFormatter"},{"attributes":{},"id":"f293536e-3ffd-444d-abdd-6a49b0e3e5d3","type":"BasicTickFormatter"},{"attributes":{"num_minor_ticks":10},"id":"7c5f05d8-b844-4008-87f9-5318e0df2b5b","type":"LogTicker"},{"attributes":{"overlay":{"id":"ab9589a4-758b-42e7-abc9-20c5abb6c2ca","type":"BoxAnnotation"},"plot":{"id":"0697e69a-c545-4285-955b-51c5eed7cbf1","subtype":"Figure","type":"Plot" ...

# %%
dashboard.train()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-e8cc36c07ee8> in <module>()
# ----> 1 dashboard.train()
#
# /home/ubuntu/src/mxnet_workshop/svhn.py in train(self)
#     201     def train(self):
#     202         learn_inputs = self.learn_inputs
# --> 203         (cost, result) = train_model(learn_inputs, fig=self.fig, handle=self.fh, train_source=self.train_source, val_source=self.val_source)
#     204         if cost < self.best_cost:
#     205             self.best_cost = cost
#
# /home/ubuntu/src/mxnet_workshop/svhn.py in train_model(learning_inputs, fig, handle, train_source, val_source)
#     112     T = T.T
#     113
# --> 114     z
#     115
#     116     result = {'img': X, 'pred': y, 'gt': T}
#
# NameError: global name 'z' is not defined

# %%
# %debug
